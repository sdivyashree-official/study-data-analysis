# %%
import pandas as pd

data = {
    "day" : ["Mon","Tue","Wednes","Thurs","Fri"],
    "minutes" : [30,0,20,15,40]
}

df = pd.DataFrame(data)

df.to_csv("study_data.csv",index=False)

new_df = pd.read_csv("study_data.csv")
print(new_df)
# Out:
#       day  minutes
# 0     Mon       30
# 1     Tue        0
# 2  Wednes       20
# 3   Thurs       15
# 4     Fri       40
